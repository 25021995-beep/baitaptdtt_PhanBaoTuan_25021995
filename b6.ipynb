# %%
a=list(map(int,input().split()))
i=0
while i<len(a):
    j=i+1
    while j<len(a):
        if a[i]==a[j]:
            a.pop(j)
        j=j+1
    i=i+1
print(a)

# %%
def tinhtong(b):
    sum=0
    i=0
    a2=[]
    while i<len(b):
        sum=sum+b[i]
        a2.append(sum)
        i=i+1
    return a2
a=list(map(int,input().split()))
print(tinhtong(a))

# %%
a=tuple(map(int,input("nhap day").split()))
b=list(a)
k=int(input("so lan quay"))
i=0
while i<k:
    b.insert(len(b),b[0])
    b.pop(0)
    i=i+1
print(b)

# %%
s=input().split()
d={}
c=[]

i=0
while i < len(s):
    j=0
    while j <len(s[i]):
        if s[i][j] ==":":
            d.setdefault(s[i][0:j],[]).append(s[i][j+1:len(s[i])])
        j+=1
    i+=1

print(d)

# %%
a=list(map(int,input().split()))
d={"positive":0, "negative":0,"zero":0}
for i in a:
    if i>0:
        d["positive"]+=1
    if i<0:
        d["negative"]+=1
    if i==0:
        d["zero"]+=1
print(d)

# %%
a=list(map(int,input().split()))
sum=0
for i in a:
    sum=sum+i
print(sum)

# %%
a=tuple(map(str,input().split()))
print(a[0],a[-1])
b=list(a)
b=b[::-1]
b=tuple(b)
print(b)

# %%
s = input().split()
dic= {}
for i in s:
    if i not in dic: dic[i] = 1
    else: dic[i]+= 1
print(dic)

# %%
d1={}
while True:
    i=input("nhap key d1:")
    if not i:
        break
    v=int(input(f"nhap value d1'{i}':"))
    d1[i]=v
d2={}
while True:
    i=input("nhap key d2:")
    if not i:
        break
    v=int(input(f"nhap value d2'{i}':"))
    d2[i]=v
d3={}
for key in d1:
    if key in d2:
        d3[key]=d1[key]+d2[key]
    elif key not in d2:
        d3[key]=d1[key]
for key in d2:
    if key not in d1:
        d3[key]=d2[key]

print(d3)

# %%
a=list(map(int,input("nhap day:").split()))
k=int(input("nhap k:"))
i=0
d=[]
while i<len(a):
    j=i+1
    c=[]
    while j<len(a):
        if a[i]+a[j]==k:
            c.append((a[i],a[j]))
            c=tuple(c)
            d.append(c)
        j+=1
    i+=1
print(d)

# %%
a=tuple(map(int,input().split()))
b=list(a)
c=[]
d=[]
for i in a:
    if i%2==0:
        c.append(i)
    elif i%2!=0:
        d.append(i)
print(tuple(c))
print(tuple(d))

# %%
a=list(map(int,input().split()))
b= {}
for i in a:
    if i not in b:
        b[i]=1
    else:
        b[i]+=1
k=0
h=0
for key in b:
    if k<b[key]:
        k=b[key]
        h=key
print(h)

# %%
d={}
c=[]
while True:
    a=input("nhap key1")
    c.append(a)
    if not a:
        break
    b=int(input(f"nhap value1{a}"))
    d[a]=b
d2={}
i=0
while i<len(d):
    d2[d[c[i]]]=c[i]
    i=i+1
print(d2)

# %%
d1=list(map(int,input().split()))
d2=list(map(int,input().split()))
if not d1:
    d1=[]
if not d2:
    d2=[]
c=[]
for i in d1:
    if i in d2:
        c.append(i)
print(c)

# %%
d={}
while True:
    a=input("nhap key1")
    if not a:
        break
    b=int(input(f"nhap value1{a}"))
    d[a]=b
k=int(input("nhap k"))
d2={}
for i in d:
    if d[i]>k:
        d2[i]=d[i]
print(d2)

# %%
n=int(input("hang"))
m=int(input("cot"))
matrix=[]
for i in range(n):
    a=list(map(int,input("nhap hang").split()))
    if len(a)>m:
        a=list(map(int,input("nhap lai").split()))
    matrix.append(a)
print(matrix)
newmatrix=[]
for row in matrix:
    rownew=[str(item).rjust(4) for item in row]
    print(" ".join(rownew))

# %%
n=int(input("so hang va cot"))
arr=[]
for i in range(n):
    a=list(map(int,input(f"nhap hang {i+1}").split()))
    if len(a)>n:
        a=list(map(int,input(f"nhap lai hang {i+1}").split()))
    arr.append(a)
i=0
a=[]
b=[]
while i<len(arr):
    a.append(arr[i][i])
    i=i+1
print(a)
j=0
while j<len(arr):
    b.append(arr[j][n-1-j])
    j=j+1
print(b)

# %%
def sumrow(row):
    sum=0
    for i in row:
        sum=sum+i
    return sum
def sumcol(col):
    sum=0
    i=k-1
    j=0
    for item in col:
        sum=sum+col[j][i]
        j=j+1
    return sum

m,n,k=map(int,input().split())
if k>m or k>n:
    k=int(input("nhap lai"))
arr=[]
for i in range(n):
    a=list(map(int,input(f"nhap hang{i+1}").split()))
    if len(a)>m:
        a=list(map(int,input(f"nhap lai hang {i+1}").split()))
    arr.append(a)
print(f"tong hang k{sumrow(arr[k-1])}")
print(f"tong cot k{sumcol(arr)}")

# %%
a=list(map(int,input().split()))
save=0
for i in range(len(a)):
    if a[0]<a[i]:
        save=i
        a[0],a[i]=a[i],a[0]
print(save+1)

# %%
a=list(map(int,input().split()))
k=int(input())
c=0
for i in range(len(a)):
    if a[i]==k:
        c=i+1
        break
    else:
        c=-1
print(c)

# %%
a=list(map(str,input().split()))
d={}
for i in range(len(a)):
    if a[i] not in d:
        d.setdefault(a[i],[]).append(i)
    else:
        d.setdefault(a[i],[]).append(i)
for i in d:
    d[i]=tuple(d[i])
print(d)
