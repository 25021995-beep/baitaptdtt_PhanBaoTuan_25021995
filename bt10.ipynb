# %%
def merge(a,b):
    if not a:
        return b
    if not b:
        return a
    if a[0]<b[0]:
        return [a[0]]+merge(a[1:],b)
    else:
        return [b[0]]+merge(b[1:],a)

a=list(map(int,input().split()))
b=list(map(int,input().split()))
print(merge(a,b))

# %%
def solve(arr):
    n=len(arr)
    m=len(arr[0])
    def count_greater(val):
        count=0
        row=0
        col=m-1
        while row<n and col>=0:
            if arr[row][col]<val:
                count=count+col+1
                row=row+1
            else:
                col=col-1
        return count
    def binary_recursion(low,high):
        if low==high:
            return low
        mid=(low+high+1)//2
        if count_greater(mid)<=k-1:
            return binary_recursion(mid,high)
        else:
            return binary_recursion(low,mid-1)
    result=binary_recursion(arr[0][0],arr[n-1][m-1])
    return result


a=list(map(int,input().split()))
b=list(map(int,input().split()))
c=list(map(int,input().split()))
arr=[]
arr.append(a)
arr.append(b)
arr.append(c)
k=int(input())
print(solve(arr))

# %%
def l_to_r(arr):
    count=0
    index=0
    index2=0
    l=len(arr)-1

    if arr[l]==min(arr):
            ind=l
            return ind
    if arr[l]!=min(arr):
            return l_to_r(arr[0:l-1])
def swap(arr):
    b=""
    if arr[0]==min(arr):
        for i in arr:
            b+=str(i)
        return b
    else:
        arr[0],arr[e]=arr[e],arr[0]
        for i in arr:
            b+=str(i)
        if b[0]=="0":
            b=b[1:]
        return b


a=int(input())
a=str(a)
arr=[]
for i in a:
    arr.append(int(i))
e=l_to_r(arr)
print(swap(arr))

# %%
def compare(arr1,arr2):
    if not(arr1) and not(arr2):
        return 0
    if arr1[0].upper() in arr2[0]:
        print("YES")
        return compare(arr1[1:],arr2[1:])
    elif arr1[0].upper() not in arr2[1:]:
        print("NO")
        return compare(arr1[1:],arr2[1:])
    elif arr2[0] in arr1[0].upper():
        print("YES")
        return compare(arr1[1:],arr2[1:])
    elif arr2[0] not in arr1[0].upper():
        print("NO")
        return compare(arr1[1:],arr2[1:])

q=int(input())
arr1=[]
arr2=[]
for i in range(q):
    a=input()
    arr1.append(a)
    b=input()
    arr2.append(b)
compare(arr1,arr2)

# %%
def compare(arr1,arr2):
    null=""
    null1=""
    def merge1(arr1,b):
        if not arr1:
            return b
        b+=str(arr1[0])
        return merge1(arr1[1:],b)

    def merge2(arr2,b):
        if not arr2:
            return b
        b+=str(arr2[0])
        return merge2(arr2[1:],b)

    if merge1(arr1,null) in merge2(arr2,null1):
        print("YES")
    else:
        print("NO")
list1=list(map(int,input().split()))
list2=list(map(int,input().split()))
compare(list1,list2)

# %%
def permutation(arr1):
    def idtf(arr1):
        counting=0
        letter=""
        for i in range(len(arr1)-1):
            if arr1[i]>arr1[i+1]:
                counting+=1

        if counting==len(arr1)-1:

            for i in arr1[::-1]:
                letter+=str(i)+" "
            print(letter)
            return True
        else:
            return False

    def idtf2(arr1):
        l=len(arr1)-1
        count=0
        count1=0



        for i in range(len(arr1)-1):
            if arr1[i]<arr1[i+1]:
                count+=1


        c=[]

        for i in range(count,len(arr1)):
            if arr1[i]>arr1[count-1]:
                c.append(arr1[i])
        for i in range(count,len(arr1)):
            if arr1[i]==min(c):
                count1=i
        index=count-1

        arr1[index],arr1[count1]=arr1[count1],arr1[index]

        arr1[count:]=arr1[count:][::-1]


        b=""
        for i in arr1:
            b+=str(i)+" "

        print(b)
    if idtf(arr1)==False:
        idtf2(arr1)




n=int(input())
a=list(map(int,input().split()))
if len(a)!=n:
    a=list(map(int,input().split()))
(permutation(a))

# %%
def solve():
    a=list(map(int,input().split()))
    k=int(input())

    count=0
    def iteration(arr,count):
        l=len(arr)-1

        if len(arr)==1 and arr[0]==0:
            count+=1
        elif len(arr)==1 and arr[0]==1:
            return count
        elif arr[l]==0 and arr[l-1]==0:
            count+=1
            return iteration(arr[:l-1],count)

        elif arr[l]==0 and arr[l-1]==1:
            return iteration(arr[:l],count)
        elif arr[l]==1 and arr[l-1]==0:
            return iteration(arr[:l-1],count)
        elif arr[l]==1 and arr[l-1]==1:
            return iteration(arr[:l],count)

        return count
    #print(iteration(a,count))
    def compare(arr,k):
        if iteration(arr,count)==k:
            print("TRUE")
        else:
            print("FALSE")
    compare(a,k)




solve()

# %%
class point():
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def turnright(self):
        self.x=self.x+1
        self.y=self.y
    def turnleft(self):
        self.x=self.x-1
        self.y=self.y
    def down(self):
        self.x=self.x
        self.y=self.y-1
    def up(self):
        self.x=self.x
        self.y=self.y+1

def solve():
    a=input()
    b=[]
    point1=point(0,0)
    c=[[0,0]]
    for i in a:
        b.append(i)
    def path(arr,point1,c):
        if len(arr)==1 and arr[0]=="U":
            point1.up()
            c.append([point1.x, point1.y])
            return c
        elif len(arr)==1 and arr[0]=="D":
            point1.down()
            c.append([point1.x, point1.y])
            return c
        elif len(arr)==1 and arr[0]=="L":
            point1.turnleft()
            c.append([point1.x, point1.y])
            return c
        elif len(arr)==1 and arr[0]=="R":
            point1.turnright()
            c.append([point1.x, point1.y])
            return c
        elif arr[0]=="R":
            point1.turnright()
            c.append([point1.x, point1.y])
            return c,path(arr[1:],point1,c)
        elif arr[0]=="U":
            point1.up()
            c.append([point1.x, point1.y])
            return c,path(arr[1:],point1,c)
        elif arr[0]=="D" and arr[1]!="R":
            point1.down()
            c.append([point1.x, point1.y])
            return c,path(arr[1:],point1,c)
        elif arr[0]=="L":
            point1.turnleft()
            c.append([point1.x, point1.y])
            return c,path(arr[1:],point1,c)
        elif arr[0]=="D" and arr[1]=="R":
            point1.down()
            point1.turnleft()
            c.append([point1.x, point1.y])
            return c,path(arr[2:],point1,c)
        elif arr[0]=="D" and arr[1]=="L":
            point1.down()
            point1.turnright()
            c.append([point1.x, point1.y])
            return c,path(arr[2:],point1,c)
        elif arr[0]=="U" and arr[1]=="L":
            point1.up()
            point1.turnleft()
            c.append([point1.x, point1.y])
            return c,path(arr[2:],point1,c)

    path(b,point1,c)


    print(point1.x,point1.y)
    print(c)

    def investigate(c):
        for i in range(len(c)):
            for j in range(i+1,len(c)):

                if c[i][0]==c[j][0] and c[i][1]==c[j][1]:
                    return True
        else:
            return False
    print(investigate(c))
solve()

# %%
def solve():
    a=list(map(int,input().split()))
    count=0
    c=[]
    def compare(a):
        if a[0]>a[1]:
            a[0],a[1]=a[1],a[0]
        if a[2]>a[3]:
            a[2],a[3]=a[3],a[2]
        if a[0]>a[2]:
            a[0],a[2]=a[2],a[0]
        if a[1]>a[3]:
            a[1],a[3]=a[3],a[1]
        a[0]=a[4]
        if a[0]>a[1]:
            a[0],a[1]=a[1],a[0]
        if a[0]>a[2]:
            a[0],a[2]=a[2],a[0]
        if a[1]>a[2]:
            return a[2]
        else:
            return a[1]
    print(compare(a))

solve()

# %%
def solve():
    a=list(map(int,input().split()))
    b=list(map(int,input().split()))

    maxrange=[]
    def findRadiuse(arr1,arr2,maxrange):
        range=[]
        if not arr2:
            return range
        for i in a:
            temp=abs(arr2[0]-i)
            range.append(temp)

        maxrange.append(max(range))
        return maxrange,findRadiuse(arr1,arr2[1:],maxrange)
    findRadiuse(a,b,maxrange)
    minrange=min(maxrange)

    #print(maxrange)
    print(minrange)
solve()
